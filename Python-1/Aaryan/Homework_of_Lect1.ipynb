# %% [markdown]
# # Q1: Variables & Data Types
#
# ## 1.1
# - Store and print: Name, Age, City
#
# ## 1.2
# - Print `type()` of each
#
# ## 1.3
# - Create, print value & type for:
#   - Int
#   - Float
#   - String
#   - Bool
#
# ## 1.4
# - Input 2 numbers and print their sum

# %%
Name = "Gehrmann Sparrow"
Age = 22
is_evil = False
City = "Backlund"
vision = 14.0

print(f" {type(Name)} : {Name}")
print(f" {type(Age)} : {Age}")
print(f" {type(City)} : {City}")
print(f" {type(is_evil)} : {is_evil}")
print(f" {type(vision)} : {vision}")

# %%
n1 = int(input("Enter no. 1 :-"))
n2 = int(input("Enter no. 2 :-"))
sum = n1 + n2
print(sum)

# %% [markdown]
# # Q2: Operators (Input 2 numbers)
#
# ## 2.1 Arithmetic Operations
# - Addition (+)
# - Subtraction (-)
# - Multiplication (*)
# - Division (/)
# - Floor Division (//)
# - Modulus (%)
#
# ## 2.2 Comparison Operations
# - Greater than (>)
# - Less than (<)
# - Equal to (==)
#
# ## 2.3 Logical Operations
# - Check if both numbers are positive
# - Check if at least one number is positive

# %%
n1 = int(input("enter no. 1 :- "))
n2 = int(input("enter no. 2 :- "))
print(n1+n2)
print(n1-n2)
print(n1*n2)
print(n1/n2)
print(n1//n2)
print(n1%n2)
print(n1>n2)
print(n1<n2)
print(n1==n2)
print(n1 > 0 and n2 > 0)
print(n1 > 0 or n2 > 0)

# %% [markdown]
# # Q3: Strings
# `text = "Python Programming"`
#
# ## 3.1
# - Print first character
# - Print last character
# - Print length of string
#
# ## 3.2
# - Convert to uppercase
# - Convert to lowercase
#
# ## 3.3
# - Count occurrences of `"o"`
# - Check if `"Python"` exists in the string
#
# ## 3.4
# - Print the string in reverse

# %%
text = "Python Programming"
print(text[0])
print(text[-1])
print(len(text))

print(text.upper())
print(text.lower())

print(text.count("o"))
print("Python" in text)

print(text[::-1])

# %% [markdown]
# # Q4: Lists, Tuples, Dictionaries
#
# ## A. List (5 fruits)
# 1. Print list
# 2. Add a fruit
# 3. Remove a fruit
# 4. Print first & last element
# 5. Sort alphabetically
#
# ## B. Tuple (5 numbers)
# 1. Print tuple
# 2. Find maximum
# 3. Find minimum
# 4. Count occurrences of a number
#
# ## C. Dictionary (Name, Age, City, Course)
# 1. Print key-value pairs

# %%
fruits = ["Dragon Fruit", "Banana", "Chickoo", "Elderberry", "Apple"]
print(fruits)

fruits.append("Fig")
print(fruits)

fruits.remove("Chickoo")
print(fruits)

print(fruits[0])
print(fruits[-1])

fruits.sort()
print(fruits)

# %%
num=(4,8,2,4,5)
print(num)
print(max(num))
print(min(num))
print(num.count(4))

# %%
data = {
    "Name": "Klien Moretti",
    "Age": 22,
    "City": "Tingen City",
    "Course": "Bachelors in History"
}

for key, value in data.items():
    print(key, ":", value)

# %% [markdown]
# # Q5: Conditions (if-else)
#
# ## 5.1
# - Input a number: Check if Positive, Negative, or Zero
#
# ## 5.2 Grade Calculation
# - Input marks:
#   - 90 → A
#   - 75–89 → B
#   - 60–74 → C
#   - < 60 → D
#
# ## 5.3
# - Input year: Check if Leap Year
#
# ## 5.4
# - Input 3 numbers: Print the largest

# %%
num = int(input("Enter a number"))
if(num > 0):
  print("Positive")
elif(num == 0):
  print("Zero")
else:
  print("Negative")

# %%
marks = int(input("Enter marks"))
if(marks >= 90):
  print("A")
elif(marks >=75):
  print("B")
elif(marks >=60):
  print("C")
else:
  print("D")

# %%
year = int(input("Enter the year"))
if((year%4 == 0 and year%100 !=0 ) or year%400 == 0 ):
  print("Leap Year")
else:
  print("Not Leap Year")

# %%
n1 = int(input("Enter no. 1 :- "))
n2 = int(input("Enter no. 2 :- "))
n3 = int(input("Enter no. 3 :- "))

if(n1>n2):
  if(n1>n3):
    print(f"Largest {n1}")
  else:
    print(f"Largest {n3}")
else:
  if(n2>n3):
    print(f"Largest {n2}")
  else:
    print(f"Largest {n3}")

# %% [markdown]
# # Q6: Loops
#
# ## Part A - Loops
#
# ### 6.1
# - Print numbers from 1 to 20
#
# ### 6.2
# - Print even numbers between 1 and 50
#
# ### 6.3
# - Input N: Find sum from 1 to N
#
# ### 6.4
# - Input a number: Print multiplication table up to 10
#
# ### 6.5
# - Input a string: Count vowels

# %%
for i in range(1,21) :
  print(i)

# %%
for i in range(1, 51):
    if i % 2 == 0:
        print(i)

# %%
sum = 0
N = int(input("Enter value"))
for i in range(1,N):
  sum = sum + i
print(sum)

# %%
n = int(input("Enter a number: "))
for i in range(1, 11):
    print(f"{n} X {i} = {i*n}")

# %%
s = input("Enter a string : ")
count = 0
for ch in s:
  if ch in "aeiouAEIOU":
    count += 1
print(count)

# %% [markdown]
# # Bonus (Optional): Student Result System
# - Input: Name and marks for 3 subjects
# - Calculate:
#   - Total
#   - Percentage
#   - Grade

# %%
name = input("Enter student name: ")
english = int(input("Enter English marks: "))
maths = int(input("Enter Maths marks: "))
science = int(input("Enter Science marks: "))

total = english + maths + science
percentage = (total / 300) * 100

print(f"Name: {name}")
print(f"Total: {total} / 300")
print(f"Percentage: {percentage:.2f}%")

if percentage >= 90:
    print("Grade: A")
elif percentage >= 75:
    print("Grade: B")
elif percentage >= 60:
    print("Grade: C")
else:
    print("Grade: D")
